# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import scipy.stats as stats
from scipy.special import boxcox1p
import missingno as msno
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.svm import SVR
from sklearn.linear_model import Lasso, LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression, f_regression
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, KFold, RepeatedKFold
from sklearn.pipeline import Pipeline
from yellowbrick.regressor import PredictionError, ResidualsPlot
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read data

# %%
train = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')
sub = pd.read_csv('Data/sample_submission.csv')

# %%
print('Train Data: ')
display(train.head())
print('Test Data: ')
display(test.head())
print('sample submission: ')
display(sub.head())
# Out:
# Train Data:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    42          20       RL        115.0    16905   Pave   NaN      Reg
# 1  1075          20       RL         74.0     8556   Pave   NaN      Reg
# 2   270          20       RL          NaN     7917   Pave   NaN      IR1
# 3   167          20       RL          NaN    10708   Pave   NaN      IR1
# 4   219          50       RL          NaN    15660   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      7   2007        WD         Normal     170000
# 1      5   2007        WD         Normal     194000
# 2      5   2007        WD         Normal     148000
# 3     11   2009       COD         Normal     190000
# 4      5   2008        WD         Normal     311500
#
# [5 rows x 81 columns]
# Test Data:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   736          75       RM         60.0    10800   Pave   NaN      Reg
# 1  1172          20       RL         76.0     9120   Pave   NaN      Reg
# 2  1388          50       RM         60.0     8520   Pave  Grvl      Reg
# 3   556          45       RM         58.0     6380   Pave   NaN      Reg
# 4  1139          20       RL          NaN     9819   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...         288        0    NaN   NaN        Shed
# 2         Lvl    AllPub  ...           0        0    NaN  GdWo         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0     10    2006        WD         Normal
# 1    1400     11    2008        WD         Normal
# 2       0      8    2007       CWD         Family
# 3       0      8    2006        WD         Normal
# 4       0      5    2009        WD         Normal
#
# [5 rows x 80 columns]
# sample submission:
#      Id SalePrice
# 0   736         X
# 1  1172         X
# 2  1388         X
# 3   556         X
# 4  1139         X

# %%
print('Train shape: ',train.shape)
print('Test shape: ',test.shape)
# Out:
# Train shape:  (1168, 81)
# Test shape:  (292, 80)

# %% [markdown]
# ### Explore Data

# %%
print('The number of columns in Train set : {}'.format(len(train.columns.tolist())))
print('The number of columns in Test set : {}'.format(len(test.columns.tolist())))
# Out:
# The number of columns in Train set : 81
# The number of columns in Test set : 80

# %%
intVar = train.select_dtypes(include = ['int']).columns.tolist()
floatVar = train.select_dtypes(include = ['float']).columns.tolist()
objectVar = train.select_dtypes(include = ['object']).columns.tolist()

# %%
display(train[intVar].info())
display(train[intVar].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   LotArea        1168 non-null   int64
#  3   OverallQual    1168 non-null   int64
#  4   OverallCond    1168 non-null   int64
#  5   YearBuilt      1168 non-null   int64
#  6   YearRemodAdd   1168 non-null   int64
#  7   BsmtFinSF1     1168 non-null   int64
#  8   BsmtFinSF2     1168 non-null   int64
#  9   BsmtUnfSF      1168 non-null   int64
#  10  TotalBsmtSF    1168 non-null   int64
#  11  1stFlrSF       1168 non-null   int64
#  12  2ndFlrSF       1168 non-null   int64
#  13  LowQualFinSF   1168 non-null   int64
#  14  GrLivArea      1168 non-null   int64
#  15  BsmtFullBath   1168 non-null   int64
#  16  BsmtHalfBath   1168 non-null   int64
#  17  FullBath       1168 non-null   int64
#  18  HalfBath       1168 non-null   int64
#  19  BedroomAbvGr   1168 non-null   int64
#  20  KitchenAbvGr   1168 non-null   int64
#  21  TotRmsAbvGrd   1168 non-null   int64
#  22  Fireplaces     1168 non-null   int64
#  23  GarageCars     1168 non-null   int64
#  24  GarageArea     1168 non-null   int64
#  25  WoodDeckSF     1168 non-null   int64
#  26  OpenPorchSF    1168 non-null   int64
#  27  EnclosedPorch  1168 non-null   int64
#  28  3SsnPorch      1168 non-null   int64
#  29  ScreenPorch    1168 non-null   int64
#  30  PoolArea       1168 non-null   int64
#  31  MiscVal        1168 non-null   int64
#  32  MoSold         1168 non-null   int64
#  33  YrSold         1168 non-null   int64
#  34  SalePrice      1168 non-null   int64
# dtypes: int64(35)
# memory usage: 319.5 KB
# None
#                 count           mean           std      min        25%  \
# Id             1168.0     728.039384    425.167321      1.0     355.50
# MSSubClass     1168.0      57.375856     43.522414     20.0      20.00
# LotArea        1168.0   10529.335616  10734.611698   1300.0    7500.00
# OverallQual    1168.0       6.100171      1.392623      1.0       5.00
# OverallCond    1168.0       5.575342      1.119803      1.0       5.00
# YearBuilt      1168.0    1971.960616     30.113498   1872.0    1954.00
# YearRemodAdd   1168.0    1985.496575     20.460717   1950.0    1968.00
# BsmtFinSF1     1168.0     449.238014    464.193569      0.0       0.00
# BsmtFinSF2     1168.0      44.054795    155.813680      0.0       0.00
# BsmtUnfSF      1168.0     567.543664    446.832853      0.0     219.75
# TotalBsmtSF    1168.0    1060.836473    451.395655      0.0     793.75
# 1stFlrSF       1168.0    1163.811644    388.074248    334.0     882.00
# 2ndFlrSF       1168.0     342.721747    436.823198      0.0       0.00
# LowQualFinSF   1168.0       5.685788     48.374252      0.0       0.00
# GrLivArea      1168.0    1512.219178    527.257815    334.0    1128.00
# BsmtFullBath   1168.0       0.425514      0.518319      0.0       0.00
# BsmtHalfBath   1168.0       0.059932      0.244572      0.0       0.00
# FullBath       1168.0       1.569349      0.547944      0.0       1.00
# HalfBath       1168.0       0.381849      0.503369      0.0       0.00
# BedroomAbvGr   1168.0       2.863870      0.804526      0.0       2.00
# KitchenAbvGr   1168.0       1.046233      0.221979      0.0       1.00
# TotRmsAbvGrd   1168.0       6.500856      1.609206      2.0       5.00
# Fireplaces     1168.0       0.610445      0.633101      0.0       0.00
# GarageCars     1168.0       1.761986      0.750796      0.0       1.00
# GarageArea     1168.0     472.794521    216.324641      0.0     327.75
# WoodDeckSF     1168.0      98.566781    127.081601      0.0       0.00
# OpenPorchSF    1168.0      47.887842     67.992642      0.0       0.00
# EnclosedPorch  1168.0      20.954623     59.988335      0.0       0.00
# 3SsnPorch      1168.0       4.118151     32.372083      0.0       0.00
# ScreenPorch    1168.0      13.825342     52.857153      0.0       0.00
# PoolArea       1168.0       2.449486     37.828606      0.0       0.00
# MiscVal        1168.0      48.681507    548.727100      0.0       0.00
# MoSold         1168.0       6.313356      2.695216      1.0       5.00
# YrSold         1168.0    2007.815068      1.336347   2006.0    2007.00
# SalePrice      1168.0  181232.391267  80018.113192  34900.0  130000.00
#
#                     50%        75%       max
# Id                722.5    1105.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotArea          9525.0   11608.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1974.0    2001.00    2010.0
# YearRemodAdd     1994.5    2004.00    2010.0
# BsmtFinSF1        385.0     719.25    5644.0
# BsmtFinSF2          0.0       0.00    1127.0
# BsmtUnfSF         466.5     804.50    2153.0
# TotalBsmtSF       994.0    1302.00    6110.0
# 1stFlrSF         1088.0    1390.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1456.0    1780.25    5642.0
# BsmtFullBath        0.0       1.00       2.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       6.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      12.0
# Fireplaces          1.0       1.00       3.0
# GarageCars          2.0       2.00       4.0
# GarageArea        479.5     576.00    1418.0
# WoodDeckSF          0.0     171.25     857.0
# OpenPorchSF        27.0      69.25     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      162700.0  213625.00  755000.0

# %%
display(train[floatVar].info())
display(train[floatVar].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LotFrontage  966 non-null    float64
#  1   MasVnrArea   1162 non-null   float64
#  2   GarageYrBlt  1099 non-null   float64
# dtypes: float64(3)
# memory usage: 27.5 KB
# None
#               count         mean         std     min     25%     50%      75%  \
# LotFrontage   966.0    69.876812   25.134547    21.0    59.0    69.0    80.00
# MasVnrArea   1162.0   104.122203  180.019763     0.0     0.0     0.0   167.75
# GarageYrBlt  1099.0  1979.002730   24.552516  1900.0  1961.0  1980.0  2002.00
#
#                 max
# LotFrontage   313.0
# MasVnrArea   1600.0
# GarageYrBlt  2010.0

# %%
display(train[objectVar].info())
display(train[objectVar].describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 43 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1168 non-null   object
#  1   Street         1168 non-null   object
#  2   Alley          71 non-null     object
#  3   LotShape       1168 non-null   object
#  4   LandContour    1168 non-null   object
#  5   Utilities      1168 non-null   object
#  6   LotConfig      1168 non-null   object
#  7   LandSlope      1168 non-null   object
#  8   Neighborhood   1168 non-null   object
#  9   Condition1     1168 non-null   object
#  10  Condition2     1168 non-null   object
#  11  BldgType       1168 non-null   object
#  12  HouseStyle     1168 non-null   object
#  13  RoofStyle      1168 non-null   object
#  14  RoofMatl       1168 non-null   object
#  15  Exterior1st    1168 non-null   object
#  16  Exterior2nd    1168 non-null   object
#  17  MasVnrType     1162 non-null   object
#  18  ExterQual      1168 non-null   object
#  19  ExterCond      1168 non-null   object
#  20  Foundation     1168 non-null   object
#  21  BsmtQual       1136 non-null   object
#  22  BsmtCond       1136 non-null   object
#  23  BsmtExposure   1136 non-null   object
#  24  BsmtFinType1   1136 non-null   object
#  25  BsmtFinType2   1135 non-null   object
#  26  Heating        1168 non-null   object
#  27  HeatingQC      1168 non-null   object
#  28  CentralAir     1168 non-null   object
#  29  Electrical     1167 non-null   object
#  30  KitchenQual    1168 non-null   object
#  31  Functional     1168 non-null   object
#  32  FireplaceQu    622 non-null    object
#  33  GarageType     1099 non-null   object
#  34  GarageFinish   1099 non-null   object
#  35  GarageQual     1099 non-null   object
#  36  GarageCond     1099 non-null   object
#  37  PavedDrive     1168 non-null   object
#  38  PoolQC         5 non-null      object
#  39  Fence          226 non-null    object
#  40  MiscFeature    44 non-null     object
#  41  SaleType       1168 non-null   object
#  42  SaleCondition  1168 non-null   object
# dtypes: object(43)
# memory usage: 392.5+ KB
# None
#               count unique      top  freq
# MSZoning       1168      5       RL   927
# Street         1168      2     Pave  1164
# Alley            71      2     Grvl    38
# LotShape       1168      4      Reg   731
# LandContour    1168      4      Lvl  1059
# Utilities      1168      2   AllPub  1167
# LotConfig      1168      5   Inside   827
# LandSlope      1168      3      Gtl  1115
# Neighborhood   1168     25    NAmes   185
# Condition1     1168      9     Norm  1008
# Condition2     1168      8     Norm  1156
# BldgType       1168      5     1Fam   970
# HouseStyle     1168      8   1Story   589
# RoofStyle      1168      6    Gable   913
# RoofMatl       1168      8  CompShg  1148
# Exterior1st    1168     13  VinylSd   430
# Exterior2nd    1168     15  VinylSd   420
# MasVnrType     1162      4     None   684
# ExterQual      1168      4       TA   718
# ExterCond      1168      5       TA  1023
# Foundation     1168      6    PConc   524
# BsmtQual       1136      4       Gd   515
# BsmtCond       1136      4       TA  1051
# BsmtExposure   1136      4       No   758
# BsmtFinType1   1136      6      GLQ   341
# BsmtFinType2   1135      6      Unf  1008
# Heating        1168      6     GasA  1144
# HeatingQC      1168      5       Ex   612
# CentralAir     1168      2        Y  1092
# Electrical     1167      4    SBrkr  1068
# KitchenQual    1168      4       TA   578
# Functional     1168      7      Typ  1090
# FireplaceQu     622      5       Gd   291
# GarageType     1099      6   Attchd   698
# GarageFinish   1099      3      Unf   473
# GarageQual     1099      5       TA  1044
# GarageCond     1099      5       TA  1056
# PavedDrive     1168      3        Y  1078
# PoolQC            5      2       Gd     3
# Fence           226      4    MnPrv   123
# MiscFeature      44      3     Shed    40
# SaleType       1168      9       WD  1015
# SaleCondition  1168      6   Normal   963

# %%
# Target Variable
fig, ax = plt.subplots()
sns.distplot(train['SalePrice'], ax=ax)
m = train['SalePrice'].mean()
print('Mean = {}'.format(m))
ax.set_title('SalePrice')
# Out:
# Mean = 181232.39126712328
# Text(0.5, 1.0, 'SalePrice')

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])
fig, ax = plt.subplots()
print('Mean = {}'.format(m))
sns.distplot(train['SalePrice'], ax=ax)
m = train['SalePrice'].mean()
ax.legend('Mean = {}'.format(m))
ax.set_title('SalePrice')
# Out:
# Mean = 181232.39126712328
# Text(0.5, 1.0, 'SalePrice')

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
# train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

# #Check the graphic again
# fig, ax = plt.subplots()
# ax.scatter(train['GrLivArea'], train['SalePrice'])
# plt.ylabel('SalePrice', fontsize=13)
# plt.xlabel('GrLivArea', fontsize=13)
# plt.show()

# %%
corr_with_SalePrice = train.corr()
plot_data = corr_with_SalePrice['SalePrice'].sort_values(ascending=True)
plt.figure(figsize=(12,6))
plot_data.plot.bar()
plt.title('Correlations with the Sale Price')
plt.show()
del plot_data

# %%
drop_columns = ['Id', 'LowQualFinSF', 'MiscVal', 'BsmtHalfBath', 'BsmtFinSF2']
train.drop(columns=drop_columns, axis=1, inplace=True)
test.drop(columns=drop_columns, axis=1, inplace=True)

# %%
train.duplicated().sum()
# Out:
# 0

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
Target = train['SalePrice']
Data = pd.concat((train, test)).reset_index(drop=True)
Data.drop(['SalePrice'], axis=1, inplace=True)
print("Data size is : {}".format(Data.shape))
# Out:
# Data size is : (1460, 75)

# %% [markdown]
# ### Missing Data

# %%
miss_features = [col for col in Data.columns.tolist() if Data[col].isnull().any()]
print('The number of features that have missing values: {}'.format(len(miss_features)))
msno.bar(Data[miss_features])
# Out:
# The number of features that have missing values: 19
# <AxesSubplot:>

# %%
na_data = (Data.isnull().sum() / len(Data)) * 100
na_data = na_data.drop(na_data[na_data == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Percentage' :na_data})
missing_data.head(20)
# Out:
#               Missing Percentage
# PoolQC                 99.520548
# MiscFeature            96.301370
# Alley                  93.767123
# Fence                  80.753425
# FireplaceQu            47.260274
# LotFrontage            17.739726
# GarageType              5.547945
# GarageYrBlt             5.547945
# GarageFinish            5.547945
# GarageQual              5.547945
# GarageCond              5.547945
# BsmtExposure            2.602740
# BsmtFinType2            2.602740
# BsmtFinType1            2.534247
# BsmtCond                2.534247
# BsmtQual                2.534247
# MasVnrArea              0.547945
# MasVnrType              0.547945
# Electrical              0.068493

# %%
Data.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu'], axis=1, inplace=True)

# %%
corr = Data.corr()
print('LotFrontage correlation > .40: {}'.format(any(corr['LotFrontage'].sort_values(ascending=False).iloc[1:]>0.40)))
print(corr['LotFrontage'].sort_values(ascending=False).iloc[1:3])
# Out:
# LotFrontage correlation > .40: True
# 1stFlrSF    0.457181
# LotArea     0.426095
# Name: LotFrontage, dtype: float64

# %%
print(Data['1stFlrSF'].dtype)
sns.distplot(Data['1stFlrSF'])
# Out:
# int64
# <AxesSubplot:xlabel='1stFlrSF', ylabel='Density'>

# %%
Data['1stFlrSF'].describe()
# Out:
# count    1460.000000
# mean     1162.626712
# std       386.587738
# min       334.000000
# 25%       882.000000
# 50%      1087.000000
# 75%      1391.250000
# max      4692.000000
# Name: 1stFlrSF, dtype: float64

# %%
# y = B0 + B1*x
temp_df = Data[['LotFrontage', '1stFlrSF']].dropna()
fill_miss = LinearRegression()
fill_miss.fit(temp_df['1stFlrSF'].values.reshape(-1, 1), temp_df['LotFrontage'].values.reshape(-1, 1))
B1, B0 = fill_miss.coef_[0][0], fill_miss.intercept_[0]
print('Intercept = {} , Coefficient = {}'.format(B0, B1))
for i in range(len(Data['LotFrontage'])):
    if pd.isnull(Data.loc[i, 'LotFrontage']):
        Data.loc[i, 'LotFrontage'] = B0 + (Data.loc[i, '1stFlrSF']*B1)
# Out:
# Intercept = 36.751969775800966 , Coefficient = 0.028743868469171676

# %%
# Data['LotFrontage'].fillna(Data['LotFrontage'].median(), inplace=True)
# Data['FireplaceQu'].fillna('None', inplace=True)
print('The number of Null values in LotFrontage: ', Data['LotFrontage'].isnull().sum())
# print('The number of Null values in FireplaceQu: ', Data['FireplaceQu'].isnull().sum())
# Out:
# The number of Null values in LotFrontage:  0

# %%
for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    Data[col] = Data[col].fillna('None')

# %%
for col in ['GarageYrBlt', 'GarageArea', 'GarageCars']:
    Data[col] = Data[col].fillna(0)

# %%
for col in ['BsmtFinSF1', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath']:
    Data[col] = Data[col].fillna(0)

# %%
for col in ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']:
    Data[col] = Data[col].fillna('None')

# %%
Data['MasVnrType'] = Data['MasVnrType'].fillna('None')
Data['MasVnrArea'] = Data['MasVnrArea'].fillna(0)

# %%
Data['Functional'].fillna('Typ', inplace=True)

# %%
# data description says NA means typical
Data['Electrical'].fillna(Data['Electrical'].mode()[0], inplace=True)

# %%
print('The number of missing values: ', sum(Data.isnull().sum()))
# Out:
# The number of missing values:  0

# %%
print('Utilities value counts: \n', Data['Utilities'].value_counts())
Data.drop('Utilities', axis=1, inplace=True)
# Out:
# Utilities value counts:
#  AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
print('DType for YrSold is :', Data['YrSold'].dtype)
print('DType for MoSold is :', Data['MoSold'].dtype)
print('DType for YearBuilt is: ', Data['YearBuilt'].dtype)
# Data['YrSold'] = Data['YrSold'].astype("object")
# Data['MoSold'] = Data['MoSold'].astype("object")
# Out:
# DType for YrSold is : int64
# DType for MoSold is : int64
# DType for YearBuilt is:  int64

# %%
Data['TotalSF'] = Data['TotalBsmtSF'] + Data['1stFlrSF'] + Data['2ndFlrSF']

# %%
# Data["Age"] = Data['YrSold'] - Data['YearBuilt']
# Data.drop('YearBuilt', axis=1, inplace=True)

# %%
Data.shape
# Out:
# (1460, 70)

# %% [markdown]
# ### Encoder

# %%
objectVar = Data.select_dtypes(include = ['object']).columns.tolist()
for col in objectVar:
    print('{} column has {} unique values'.format(col,Data[col].nunique()))
# Out:
# MSZoning column has 5 unique values
# Street column has 2 unique values
# LotShape column has 4 unique values
# LandContour column has 4 unique values
# LotConfig column has 5 unique values
# LandSlope column has 3 unique values
# Neighborhood column has 25 unique values
# Condition1 column has 9 unique values
# Condition2 column has 8 unique values
# BldgType column has 5 unique values
# HouseStyle column has 8 unique values
# RoofStyle column has 6 unique values
# RoofMatl column has 8 unique values
# Exterior1st column has 15 unique values
# Exterior2nd column has 16 unique values
# MasVnrType column has 4 unique values
# ExterQual column has 4 unique values
# ExterCond column has 5 unique values
# Foundation column has 6 unique values
# BsmtQual column has 5 unique values
# BsmtCond column has 5 unique values
# BsmtExposure column has 5 unique values
# BsmtFinType1 column has 7 unique values
# BsmtFinType2 column has 7 unique values
# Heating column has 6 unique values
# HeatingQC column has 5 unique values
# CentralAir column has 2 unique values
# Electrical column has 5 unique values
# KitchenQual column has 4 unique values
# Functional column has 7 unique values
# GarageType column has 7 unique values
# GarageFinish column has 4 unique values
# GarageQual column has 6 unique values
# GarageCond column has 6 unique values
# PavedDrive column has 3 unique values
# SaleType column has 9 unique values
# SaleCondition column has 6 unique values

# %% [markdown]
# #### Ordinal

# %%
# 14 features
objVar = ['CentralAir', 'LandSlope', 'ExterQual', 'ExterCond',
             'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
             'HeatingQC', 'KitchenQual', 'GarageQual', 'GarageCond']
# objVar = Data.select_dtypes(include = ['object']).columns.tolist()
encoder = LabelEncoder()
for col in objVar: 
    encoder.fit(list(Data[col].values)) 
    Data[col] = encoder.transform(list(Data[col].values))
print('Data Shape: ',Data.shape)
# Out:
# Data Shape:  (1460, 70)

# %%
num_fe = ['ScreenPorch', 'EnclosedPorch', 'KitchenAbvGr', 'LandSlope', '3SsnPorch', 'LotArea', 'PoolArea']
skewed_feats = Data[num_fe].apply(lambda x: stats.skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                     Skew
# PoolArea       14.813135
# LotArea        12.195142
# 3SsnPorch      10.293752
# LandSlope       4.808735
# KitchenAbvGr    4.483784
# ScreenPorch     4.117977
# EnclosedPorch   3.086696

# %%
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    Data[feat] = boxcox1p(Data[feat], lam)
# Out:
# There are 7 skewed numerical features to Box Cox transform

# %% [markdown]
# #### Non Ordinal

# %%
NonOrdinalVar = Data.select_dtypes(include = ['object']).columns.tolist()
Data = pd.get_dummies(Data, columns=NonOrdinalVar)
# one_hot = OneHotEncoder()
# for col in objectVar:
#     encoded = one_hot.fit_transform(train[[col]])
#     train[one_hot.categories_[0]]=encoded.toarray()
# train.drop(objectVar, axis=1, inplace=True)

# %%
print('Number of Null values {}'.format(sum(Data.isnull().sum())))
print('Train Shape {}'.format(Data.shape))
# Out:
# Number of Null values 0
# Train Shape (1460, 223)

# %% [markdown]
# ### Feature Selection

# %%
def correlation(df, threshold=None):
    # Set of all names of correlated columns
    col_corr = set()
    corr_mat = df.corr()
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if (abs(corr_mat.iloc[i,j]) > threshold):
                colname = corr_mat.columns[i]
                col_corr.add(colname)
    return col_corr

def reduce_data(df,comp_number=20):
    pca = PCA(n_components=comp_number, random_state=15).fit(df)
    reduced_data = pca.transform(df)
    reduced_data = pd.DataFrame(reduced_data)
    return reduced_data

# %%
# correlated_features = list(correlation(Data,threshold=0.56))
# Data = Data.drop(correlated_features, axis=1)
# Data = reduce_data(Data, 50)

# %%
train = Data[:ntrain]
test = Data[ntrain:]
print('Train Shape: ', train.shape)
print('Test Shape: ', test.shape)
# Out:
# Train Shape:  (1168, 223)
# Test Shape:  (292, 223)

# %%
# fig, ax = plt.subplots(figsize=(50,50))
# corr = pd.concat([train, Target], axis=1).corr()
# matrix = np.triu(corr)
# sns.heatmap(corr,
#         xticklabels=corr.columns,
#         yticklabels=corr.columns,annot=True, cmap="BuPu", mask=matrix)
# best_feat = ['LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'ExterQual', 'BsmtQual', 'BsmtExposure', 'BsmtFinSF1',
#        'TotalBsmtSF', 'HeatingQC', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'GarageCond', 'OpenPorchSF', 'TotalSF',
#        'MSZoning_RM', 'Neighborhood_NridgHt', 'Exterior1st_VinylSd',
#        'Exterior2nd_VinylSd', 'MasVnrType_None', 'Foundation_CBlock',
#        'Foundation_PConc', 'GarageType_Attchd', 'GarageType_Detchd',
#        'GarageType_None', 'GarageFinish_Fin', 'GarageFinish_None',
#        'GarageFinish_Unf', 'PavedDrive_Y', 'SaleType_New']

# %%
# df_corr = pd.concat([train, Target], axis=1)
# corelation=abs(df_corr.corr()['SalePrice']) >= 0.25
# best_features = corelation[corelation].index.tolist()
# best_features.remove('SalePrice')

# %%
# train = train[best_features]
# test = test[best_features]
# train = train[best_feat]
# test = test[best_feat]

# %%
# print('Train Shape: ', train.shape)
# print('Test Shape: ', test.shape)

# %%
# train.columns

# %%
# cv = RepeatedKFold(n_splits=5, n_repeats=2, random_state=1)
# fs = SelectKBest(score_func=mutual_info_regression)
# model =LinearRegression()
# pipeline = Pipeline(steps=[('sel',fs), ('model', model)])
# grid = dict()
# grid['sel__k'] = [i for i in range(5, 16)]
# search = GridSearchCV(pipeline, grid, scoring='neg_mean_squared_error', n_jobs=-1, cv=cv)
# results = search.fit(train, Target.values)
# print('Best RMSE: %.3f' % results.best_score_)
# print('Best Config: %s' % results.best_params_)
# means = results.cv_results_['mean_test_score']
# params = results.cv_results_['params']
# for mean, param in zip(means, params):
#     print(">%.3f with: %r" % (np.sqrt(-mean), param))

# %%
# correlated_features = list(correlation(train,threshold=0.65))
# train = train.drop(correlated_features, axis=1)
# test = test.drop(correlated_features, axis=1)

# %%
# print('Train Shape: ', train.shape)
# print('Test Shape: ', test.shape)

# %%
# train.columns
# KitchenQual
# ExterQual
# train.drop('KitchenQual', axis=1, inplace=True)
# test.drop('KitchenQual', axis=1, inplace=True)

# %%
# for col in pd.concat([train, Target], axis=1).columns.to_list():
#     display(pd.concat([train, Target], axis=1).plot.scatter(x=col, y='SalePrice'))

# %% [markdown]
# ### Split data

# %%
X_train, X_val, y_train, y_val = train_test_split(train, Target.values, test_size = 0.25, random_state=42)

# %%
print('The shape of X_train', X_train.shape)
print('The shape of y_train', y_train.shape)
print('The shape of X_val', X_val.shape)
print('The shape of y_val', y_val.shape)
# Out:
# The shape of X_train (876, 223)
# The shape of y_train (876,)
# The shape of X_val (292, 223)
# The shape of y_val (292,)

# %%
# def select_features(X_train, y_train, X_val, test):
#     fs = SelectKBest(score_func=mutual_info_regression, k=50)
#     fs.fit(X_train, y_train)
#     X_train_fs = fs.transform(X_train)
#     X_val_fs = fs.transform(X_val)
#     test_fs = fs.transform(test)
#     return X_train_fs, X_val_fs, test_fs, fs
# X_train, X_val, test, fs = select_features(X_train, y_train, X_val, test)
# fig, ax = plt.subplots(figsize=(12,7))
# plt.title('input features score')
# plt.xlabel('number of features')
# plt.ylabel('scores')
# plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
# plt.show()

# %%
# def select_features(X_train, y_train, X_val, test):
#     fs = SelectKBest(score_func=f_regression, k=29)
#     fs.fit(X_train, y_train)
#     X_train_fs = fs.transform(X_train)
#     X_val_fs = fs.transform(X_val)
#     test_fs = fs.transform(test)
#     return X_train_fs, X_val_fs, test_fs, fs
# X_train, X_val, test, fs = select_features(X_train, y_train, X_val, test)
# fig, ax = plt.subplots(figsize=(12,7))
# plt.title('input features score')
# plt.xlabel('number of features')
# plt.ylabel('scores')
# plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
# plt.show()

# %% [markdown]
# ### Scaling

# %%
# scale = StandardScaler().fit(X_train)
# X_train = scale.transform(X_train)

# %% [markdown]
# ### Test Models

# %% [markdown]
# #### SVR

# %%
svr = SVR()
svr.fit(X_train, y_train)
pred = svr.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.17128120284084494

# %%
visualizer = PredictionError(svr)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(svr)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for SVR'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for SVR Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### Linear Regression

# %%
lin = LinearRegression()
lin.fit(X_train, y_train)
pred = lin.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.12222663220721393

# %%
visualizer = PredictionError(lin)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(lin)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### Lasso

# %%
lasso = Lasso(alpha=0.5)
lasso.fit(X_train, y_train)
pred = lasso.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.15735461819520358

# %%
visualizer = PredictionError(lasso)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(lasso)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for Lasso'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for Lasso Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### Random Forest

# %%
ran = RandomForestRegressor(random_state=11)
ran.fit(X_train, y_train)
pred = ran.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.13117099123030418

# %%
visualizer = PredictionError(ran)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(ran)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for RandomForestRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for RandomForestRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### XGboost

# %%
xgb = XGBRegressor(random_state=7)
xgb.fit(X_train, y_train)
pred = xgb.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.12105494443896823

# %%
visualizer = PredictionError(xgb)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(xgb)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for XGBRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for XGBRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### LGBM

# %%
lgbm = LGBMRegressor(random_state=11)
lgbm.fit(X_train, y_train)
pred = lgbm.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.11718833141055143

# %%
visualizer = PredictionError(lgbm)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(lgbm)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LGBMRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for LGBMRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ### Tuning Model

# %% [markdown]
# #### SVR Tuning

# %%
# parameters = {
#               'kernel': ['rbf'],
#               'gamma': [1e-4, 1e-3, 0.01, 0.1, 0.2, 0.5, 0.6, 0.9],
#               'C': [1, 10, 100, 1000, 10000]
#              }
# # scorer = make_scorer(mean_squared_error, greater_is_better=False)
# fold = KFold(n_splits=5, shuffle=True, random_state=42).split(X_train, y_train)
# svr_gs = GridSearchCV(SVR(epsilon = 0.01), parameters, cv = fold, scoring='neg_mean_squared_error')
# svr_gs.fit(X_train, y_train)
# print('Best_Estimator: ', svr_gs.best_estimator_)
# print('*********************************************')
# scores = svr_gs.cv_results_
# for mean_score, params in zip(scores['mean_test_score'], scores['params']):
#     print(np.sqrt(-mean_score), params)

# %%
# model0 = svr_gs.best_estimator_
# model0.fit(X_train, y_train)
# pred = model0.predict(X_val)
# print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))

# %%
# visualizer = PredictionError(model0)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())
# visualizer = ResidualsPlot(model0)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())

# %% [markdown]
# #### Lasso Tuning

# %%
# param_grid ={'alpha':[0.0, 0.0001, 0.001, 0.005, 0.01, 0.1, 0.5, 1, 10, 100, 1000]}
# lasso = Lasso(random_state=1)
# fold = KFold(n_splits=5, shuffle=True, random_state=42).split(X_train, y_train)
# lasso_grid_search = GridSearchCV(lasso, param_grid, cv=fold, scoring='neg_mean_squared_error')
# lasso_grid_search.fit(X_train, y_train)
# print('Best_Estimator: ', lasso_grid_search.best_estimator_)
# print('*********************************************')
# scores = lasso_grid_search.cv_results_
# for mean_score, params in zip(scores['mean_test_score'], scores['params']):
#     print(np.sqrt(-mean_score), params)

# %%
# model = Lasso(alpha=0.5)
# model.fit(X_train, y_train)
# pred = model.predict(X_val)
# print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))

# %% [markdown]
# #### Random Forest Tuning

# %%
# forest_reg = RandomForestRegressor(random_state=11)
# n_estimators = [int(x) for x in np.linspace(start = 20, stop = 500, num = 5)]
# max_features = ['auto', 'sqrt']
# max_depth = [int(x) for x in np.linspace(1, 45, num = 3)]
# min_samples_split = [3, 5, 7, 9, 11, 15]
# param_grid = {'bootstrap': [True, False],
#               'min_samples_split': min_samples_split,
#               'n_estimators': n_estimators,
#               'max_features': max_features,
#               'max_depth':max_depth
#              }
# fold = KFold(n_splits=5, shuffle=True, random_state=42).split(X_train, y_train)
# ranf_grid_search = GridSearchCV(forest_reg, param_grid, cv=fold, scoring='neg_mean_squared_error')
# ranf_grid_search.fit(X_train, y_train)
# print('Best_Estimator: ', ranf_grid_search.best_estimator_)
# print('*********************************************')
# scores = ranf_grid_search.cv_results_
# for mean_score, params in zip(scores['mean_test_score'], scores['params']):
#     print(np.sqrt(-mean_score), params)

# %%
# model1 = ranf_grid_search.best_estimator_
# pred = model1.predict(X_val)
# print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))

# %%
# visualizer = PredictionError(model1)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())
# visualizer = ResidualsPlot(model1)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())

# %% [markdown]
# #### XGBoost Regrission Tuning

# %%
# param_grid = {"learning_rate"    : [0.05, 0.10, 0.15] ,
#               "max_depth"        : [ 5, 6, 7, 8, 9],
#               "min_child_weight" : [ 7, 9, 11, 13],
#               "gamma"            : [ 0.0, 0.1, 0.2],
#               "colsample_bytree" : [ 0.4, 0.5, 0.7] }
# xgb = XGBRegressor()
# fold = KFold(n_splits=3, shuffle=True, random_state=42).split(X_train, y_train)
# xgb_grid_search = RandomizedSearchCV(estimator = xgb, param_distributions = param_grid, n_iter = 50, cv =fold , random_state=42, n_jobs = -1, scoring='neg_mean_squared_error')
# xgb_grid_search.fit(X_train, y_train)
# print('Best_Estimator: ', xgb_grid_search.best_estimator_)
# print('*********************************************')
# scores = xgb_grid_search.cv_results_
# for mean_score, params in zip(scores['mean_test_score'], scores['params']):
#     print(np.sqrt(-mean_score), params)

# %%
# model2 = xgb_grid_search.best_estimator_
# pred = model2.predict(X_val)
# print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))

# %%
# visualizer = PredictionError(model2)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())
# visualizer = ResidualsPlot(model2)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# display(visualizer.poof())

# %% [markdown]
# #### LightGBM Tuning

# %%
param_grid = { 
                'metric': 'rmse',
                'n_estimators': [18000],
                'boosting_type': ["gbdt", "goss"],
                'reg_alpha': [0.001, 0.003, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0],
                'reg_lambda': [0.001, 0.003, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0],
                'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
                'subsample': [0.6, 0.7, 0.85, 1.0],
                'learning_rate': [0.005, 0.01, 0.02, 0.03, 0.05, 0.1],
                'max_depth': list(range(2, 12, 1)),
                'num_leaves' : list(range(13, 148, 5)),
                'min_child_samples': list(range(1, 96, 5)),
            }
lgbm = LGBMRegressor(random_state=11)
fold = KFold(n_splits=3, shuffle=True, random_state=42).split(X_train, y_train)
lgbm_grid_search = RandomizedSearchCV(estimator = lgbm, param_distributions = param_grid, n_iter = 50, cv =fold , random_state=42, n_jobs = -1, scoring='neg_mean_squared_error')
lgbm_grid_search.fit(X_train, y_train)
print('Best_Estimator: ', lgbm_grid_search.best_estimator_)
print('*********************************************')
scores = lgbm_grid_search.cv_results_
for mean_score, params in zip(scores['mean_test_score'], scores['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# Best_Estimator:  LGBMRegressor(colsample_bytree=0.6, learning_rate=0.005, max_depth=3,
#               metric='r', min_child_samples=1, n_estimators=18000,
#               num_leaves=108, random_state=11, reg_alpha=0.01,
#               reg_lambda=0.005)
# *********************************************
# 0.1381075355098713 {'subsample': 1.0, 'reg_lambda': 0.05, 'reg_alpha': 0.1, 'num_leaves': 118, 'n_estimators': 18000, 'min_child_samples': 11, 'metric': 's', 'max_depth': 2, 'learning_rate': 0.02, 'colsample_bytree': 0.5, 'boosting_type': 'goss'}
# 0.14576622689353613 {'subsample': 0.6, 'reg_lambda': 1.0, 'reg_alpha': 0.005, 'num_leaves': 43, 'n_estimators': 18000, 'min_child_samples': 16, 'metric': 'r', 'max_depth': 11, 'learning_rate': 0.01, 'colsample_bytree': 0.9, 'boosting_type': 'goss'}
# 0.14071641872476046 {'subsample': 0.85, 'reg_lambda': 0.01, 'reg_alpha': 0.001, 'num_leaves': 28, 'n_estimators': 18000, 'min_child_samples': 6, 'metric': 'e', 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.13336530797587542 {'subsample': 1.0, 'reg_lambda': 0.003, 'reg_alpha': 0.005, 'num_leaves': 58, 'n_estimators': 18000, 'min_child_samples': 1, 'metric': 'e', 'max_depth': 4, 'learning_rate': 0.005, 'colsample_bytree': 0.9, 'boosting_type': 'gbdt'}
# 0.14366194528808646 {'subsample': 0.85, 'reg_lambda': 0.003, 'reg_alpha': 0.01, 'num_leaves': 53, 'n_estimators': 18000, 'min_child_samples': 41, 'metric': 's', 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.9, 'boosting_type': 'gbdt'}
# 0.1707996906309472 {'subsample': 0.7, 'reg_lambda': 0.5, 'reg_alpha': 0.01, 'num_leaves': 138, 'n_estimators': 18000, 'min_child_samples': 46, 'metric': 'r', 'max_depth': 11, 'learning_rate': 0.03, 'colsample_bytree': 0.8, 'boosting_type': 'goss'}
# 0.1477400760541155 {'subsample': 0.85, 'reg_lambda': 0.05, 'reg_alpha': 0.5, 'num_leaves': 53, 'n_estimators': 18000, 'min_child_samples': 61, 'metric': 'm', 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.9, 'boosting_type': 'gbdt'}
# 0.18968625705570114 {'subsample': 0.85, 'reg_lambda': 0.005, 'reg_alpha': 0.005, 'num_leaves': 133, 'n_estimators': 18000, 'min_child_samples': 51, 'metric': 'e', 'max_depth': 6, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.15729092030553832 {'subsample': 0.85, 'reg_lambda': 0.005, 'reg_alpha': 0.5, 'num_leaves': 68, 'n_estimators': 18000, 'min_child_samples': 26, 'metric': 'e', 'max_depth': 10, 'learning_rate': 0.02, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.1681836800467199 {'subsample': 0.6, 'reg_lambda': 0.1, 'reg_alpha': 0.01, 'num_leaves': 108, 'n_estimators': 18000, 'min_child_samples': 56, 'metric': 'm', 'max_depth': 6, 'learning_rate': 0.02, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.13885710605566642 {'subsample': 1.0, 'reg_lambda': 0.003, 'reg_alpha': 0.01, 'num_leaves': 18, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 'r', 'max_depth': 8, 'learning_rate': 0.02, 'colsample_bytree': 0.7, 'boosting_type': 'gbdt'}
# 0.1673270960578156 {'subsample': 1.0, 'reg_lambda': 0.1, 'reg_alpha': 0.05, 'num_leaves': 78, 'n_estimators': 18000, 'min_child_samples': 76, 'metric': 'r', 'max_depth': 11, 'learning_rate': 0.01, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.15673964312045885 {'subsample': 0.85, 'reg_lambda': 0.001, 'reg_alpha': 0.05, 'num_leaves': 83, 'n_estimators': 18000, 'min_child_samples': 61, 'metric': 's', 'max_depth': 3, 'learning_rate': 0.03, 'colsample_bytree': 0.8, 'boosting_type': 'gbdt'}
# 0.13426349462903636 {'subsample': 0.7, 'reg_lambda': 0.1, 'reg_alpha': 0.05, 'num_leaves': 113, 'n_estimators': 18000, 'min_child_samples': 16, 'metric': 'm', 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.7, 'boosting_type': 'gbdt'}
# 0.18211732578111725 {'subsample': 0.6, 'reg_lambda': 0.1, 'reg_alpha': 0.003, 'num_leaves': 138, 'n_estimators': 18000, 'min_child_samples': 81, 'metric': 'r', 'max_depth': 3, 'learning_rate': 0.05, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.14883291669497242 {'subsample': 1.0, 'reg_lambda': 0.005, 'reg_alpha': 1.0, 'num_leaves': 18, 'n_estimators': 18000, 'min_child_samples': 21, 'metric': 'r', 'max_depth': 6, 'learning_rate': 0.01, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.169673524142451 {'subsample': 0.7, 'reg_lambda': 1.0, 'reg_alpha': 0.05, 'num_leaves': 48, 'n_estimators': 18000, 'min_child_samples': 41, 'metric': 's', 'max_depth': 11, 'learning_rate': 0.03, 'colsample_bytree': 0.7, 'boosting_type': 'goss'}
# 0.17307207269976504 {'subsample': 0.7, 'reg_lambda': 0.003, 'reg_alpha': 0.003, 'num_leaves': 98, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 'r', 'max_depth': 6, 'learning_rate': 0.1, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.1393975968169165 {'subsample': 0.7, 'reg_lambda': 0.001, 'reg_alpha': 0.05, 'num_leaves': 133, 'n_estimators': 18000, 'min_child_samples': 41, 'metric': 'm', 'max_depth': 8, 'learning_rate': 0.005, 'colsample_bytree': 0.5, 'boosting_type': 'gbdt'}
# 0.17188152014590727 {'subsample': 1.0, 'reg_lambda': 1.0, 'reg_alpha': 0.1, 'num_leaves': 118, 'n_estimators': 18000, 'min_child_samples': 36, 'metric': 's', 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.13973747164333888 {'subsample': 0.6, 'reg_lambda': 0.1, 'reg_alpha': 0.001, 'num_leaves': 53, 'n_estimators': 18000, 'min_child_samples': 6, 'metric': 's', 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.17212882749378164 {'subsample': 1.0, 'reg_lambda': 0.005, 'reg_alpha': 0.5, 'num_leaves': 138, 'n_estimators': 18000, 'min_child_samples': 86, 'metric': 'm', 'max_depth': 5, 'learning_rate': 0.02, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.1563304388125668 {'subsample': 0.7, 'reg_lambda': 0.1, 'reg_alpha': 0.001, 'num_leaves': 28, 'n_estimators': 18000, 'min_child_samples': 61, 'metric': 'm', 'max_depth': 4, 'learning_rate': 0.02, 'colsample_bytree': 0.8, 'boosting_type': 'gbdt'}
# 0.1371787234004864 {'subsample': 0.6, 'reg_lambda': 1.0, 'reg_alpha': 1.0, 'num_leaves': 123, 'n_estimators': 18000, 'min_child_samples': 6, 'metric': 'e', 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.5, 'boosting_type': 'gbdt'}
# 0.1612334057282762 {'subsample': 1.0, 'reg_lambda': 0.005, 'reg_alpha': 1.0, 'num_leaves': 63, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 's', 'max_depth': 7, 'learning_rate': 0.05, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.13466759102548523 {'subsample': 0.6, 'reg_lambda': 0.5, 'reg_alpha': 0.005, 'num_leaves': 78, 'n_estimators': 18000, 'min_child_samples': 21, 'metric': 's', 'max_depth': 10, 'learning_rate': 0.005, 'colsample_bytree': 0.8, 'boosting_type': 'gbdt'}
# 0.14260709671266755 {'subsample': 0.6, 'reg_lambda': 0.05, 'reg_alpha': 0.003, 'num_leaves': 133, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 'r', 'max_depth': 9, 'learning_rate': 0.03, 'colsample_bytree': 1.0, 'boosting_type': 'gbdt'}
# 0.13414238804297193 {'subsample': 0.85, 'reg_lambda': 0.5, 'reg_alpha': 0.5, 'num_leaves': 68, 'n_estimators': 18000, 'min_child_samples': 21, 'metric': 's', 'max_depth': 4, 'learning_rate': 0.02, 'colsample_bytree': 0.8, 'boosting_type': 'gbdt'}
# 0.1365476962746722 {'subsample': 0.85, 'reg_lambda': 1.0, 'reg_alpha': 1.0, 'num_leaves': 18, 'n_estimators': 18000, 'min_child_samples': 6, 'metric': 'm', 'max_depth': 5, 'learning_rate': 0.02, 'colsample_bytree': 0.8, 'boosting_type': 'gbdt'}
# 0.13573616523427048 {'subsample': 0.7, 'reg_lambda': 0.005, 'reg_alpha': 0.1, 'num_leaves': 33, 'n_estimators': 18000, 'min_child_samples': 1, 'metric': 's', 'max_depth': 10, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'gbdt'}
# 0.14426669159784003 {'subsample': 1.0, 'reg_lambda': 1.0, 'reg_alpha': 1.0, 'num_leaves': 13, 'n_estimators': 18000, 'min_child_samples': 16, 'metric': 's', 'max_depth': 3, 'learning_rate': 0.02, 'colsample_bytree': 0.5, 'boosting_type': 'goss'}
# 0.14020191595230136 {'subsample': 1.0, 'reg_lambda': 0.5, 'reg_alpha': 0.5, 'num_leaves': 113, 'n_estimators': 18000, 'min_child_samples': 26, 'metric': 's', 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 1.0, 'boosting_type': 'gbdt'}
# 0.150945295976454 {'subsample': 0.7, 'reg_lambda': 1.0, 'reg_alpha': 0.1, 'num_leaves': 28, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 'e', 'max_depth': 4, 'learning_rate': 0.005, 'colsample_bytree': 1.0, 'boosting_type': 'goss'}
# 0.1441694473360271 {'subsample': 0.85, 'reg_lambda': 0.01, 'reg_alpha': 0.1, 'num_leaves': 88, 'n_estimators': 18000, 'min_child_samples': 36, 'metric': 's', 'max_depth': 9, 'learning_rate': 0.05, 'colsample_bytree': 0.9, 'boosting_type': 'gbdt'}
# 0.1363171051662671 {'subsample': 0.85, 'reg_lambda': 0.05, 'reg_alpha': 0.003, 'num_leaves': 103, 'n_estimators': 18000, 'min_child_samples': 11, 'metric': 's', 'max_depth': 2, 'learning_rate': 0.01, 'colsample_bytree': 0.9, 'boosting_type': 'goss'}
# 0.12720315106045033 {'subsample': 1.0, 'reg_lambda': 0.005, 'reg_alpha': 0.01, 'num_leaves': 108, 'n_estimators': 18000, 'min_child_samples': 1, 'metric': 'r', 'max_depth': 3, 'learning_rate': 0.005, 'colsample_bytree': 0.6, 'boosting_type': 'gbdt'}
# 0.14407710811991697 {'subsample': 0.85, 'reg_lambda': 0.1, 'reg_alpha': 0.003, 'num_leaves': 143, 'n_estimators': 18000, 'min_child_samples': 46, 'metric': 'm', 'max_depth': 8, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'gbdt'}
# 0.13592503897396216 {'subsample': 0.85, 'reg_lambda': 0.001, 'reg_alpha': 0.05, 'num_leaves': 48, 'n_estimators': 18000, 'min_child_samples': 11, 'metric': 'e', 'max_depth': 11, 'learning_rate': 0.01, 'colsample_bytree': 0.5, 'boosting_type': 'goss'}
# 0.1731052927773629 {'subsample': 0.85, 'reg_lambda': 0.003, 'reg_alpha': 0.05, 'num_leaves': 133, 'n_estimators': 18000, 'min_child_samples': 71, 'metric': 'r', 'max_depth': 4, 'learning_rate': 0.03, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.1670654190548834 {'subsample': 0.6, 'reg_lambda': 0.1, 'reg_alpha': 0.001, 'num_leaves': 108, 'n_estimators': 18000, 'min_child_samples': 76, 'metric': 'r', 'max_depth': 4, 'learning_rate': 0.01, 'colsample_bytree': 0.5, 'boosting_type': 'goss'}
# 0.1414739531186664 {'subsample': 0.6, 'reg_lambda': 0.005, 'reg_alpha': 0.005, 'num_leaves': 93, 'n_estimators': 18000, 'min_child_samples': 11, 'metric': 'm', 'max_depth': 9, 'learning_rate': 0.01, 'colsample_bytree': 0.9, 'boosting_type': 'goss'}
# 0.18444579641378864 {'subsample': 0.85, 'reg_lambda': 0.003, 'reg_alpha': 0.1, 'num_leaves': 98, 'n_estimators': 18000, 'min_child_samples': 41, 'metric': 'e', 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 0.7, 'boosting_type': 'goss'}
# 0.16043355861154807 {'subsample': 0.7, 'reg_lambda': 0.05, 'reg_alpha': 0.001, 'num_leaves': 88, 'n_estimators': 18000, 'min_child_samples': 76, 'metric': 'm', 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.6, 'boosting_type': 'gbdt'}
# 0.15029047739008577 {'subsample': 1.0, 'reg_lambda': 0.001, 'reg_alpha': 0.05, 'num_leaves': 128, 'n_estimators': 18000, 'min_child_samples': 31, 'metric': 'r', 'max_depth': 6, 'learning_rate': 0.005, 'colsample_bytree': 0.9, 'boosting_type': 'goss'}
# 0.1628904348394457 {'subsample': 0.6, 'reg_lambda': 0.5, 'reg_alpha': 0.005, 'num_leaves': 108, 'n_estimators': 18000, 'min_child_samples': 71, 'metric': 'm', 'max_depth': 11, 'learning_rate': 0.005, 'colsample_bytree': 0.8, 'boosting_type': 'goss'}
# 0.1730139306969338 {'subsample': 0.7, 'reg_lambda': 0.01, 'reg_alpha': 0.001, 'num_leaves': 138, 'n_estimators': 18000, 'min_child_samples': 71, 'metric': 'm', 'max_depth': 9, 'learning_rate': 0.03, 'colsample_bytree': 0.7, 'boosting_type': 'goss'}
# 0.19014585884975815 {'subsample': 0.7, 'reg_lambda': 0.05, 'reg_alpha': 1.0, 'num_leaves': 123, 'n_estimators': 18000, 'min_child_samples': 76, 'metric': 'm', 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.1463424033933963 {'subsample': 0.7, 'reg_lambda': 0.5, 'reg_alpha': 1.0, 'num_leaves': 88, 'n_estimators': 18000, 'min_child_samples': 61, 'metric': 'r', 'max_depth': 7, 'learning_rate': 0.02, 'colsample_bytree': 0.6, 'boosting_type': 'gbdt'}
# 0.13460122099720676 {'subsample': 0.6, 'reg_lambda': 0.005, 'reg_alpha': 0.001, 'num_leaves': 123, 'n_estimators': 18000, 'min_child_samples': 6, 'metric': 's', 'max_depth': 8, 'learning_rate': 0.02, 'colsample_bytree': 0.6, 'boosting_type': 'goss'}
# 0.13072379171649054 {'subsample': 0.7, 'reg_lambda': 0.5, 'reg_alpha': 0.005, 'num_leaves': 23, 'n_estimators': 18000, 'min_child_samples': 16, 'metric': 's', 'max_depth': 2, 'learning_rate': 0.01, 'colsample_bytree': 0.7, 'boosting_type': 'gbdt'}

# %%
model3 = lgbm_grid_search.best_estimator_
pred = model3.predict(X_val)
print('The RMSE {}'.format(np.sqrt(mean_squared_error(y_val, pred))))
# Out:
# The RMSE 0.11165081807181085

# %%
visualizer = PredictionError(model3)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
visualizer = ResidualsPlot(model3)
visualizer.fit(X_train, y_train)
visualizer.score(X_val, y_val)
display(visualizer.poof())
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LGBMRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>
# <AxesSubplot:title={'center':'Residuals for LGBMRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ### Predict Test Data

# %%
test_pre = model3.predict(test)
print('The Range is:   {} - {}'.format(min(test_pre), max(test_pre)))
# Out:
# The Range is:   11.018592867377805 - 13.031861476299524

# %%
test_pre = np.expm1(test_pre)
print('The Range is:   {} - {}'.format(min(test_pre), max(test_pre)))
# Out:
# The Range is:   60996.7872176992 - 456735.29864607897

# %% [markdown]
# ### CSV sub

# %%
sub['SalePrice'] = test_pre
sub.to_csv('sub4.csv', index=False)
